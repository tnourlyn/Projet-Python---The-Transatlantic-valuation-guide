# %%
# %pip install pynsee
# Out:
# Collecting pynsee
#   Downloading pynsee-0.2.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas<3.0,>=2.2.0 in /opt/python/lib/python3.13/site-packages (from pynsee) (2.3.3)
# Requirement already satisfied: geopandas<2.0,>=1.0 in /opt/python/lib/python3.13/site-packages (from pynsee) (1.1.1)
# Requirement already satisfied: pyarrow>=17.0 in /opt/python/lib/python3.13/site-packages (from pynsee) (22.0.0)
# Requirement already satisfied: tqdm>=4.56 in /opt/python/lib/python3.13/site-packages (from pynsee) (4.67.1)
# Requirement already satisfied: platformdirs>=4 in /opt/python/lib/python3.13/site-packages (from pynsee) (4.5.1)
# Collecting unidecode>=1.3 (from pynsee)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: urllib3>=2.2 in /opt/python/lib/python3.13/site-packages (from pynsee) (2.6.2)
# Requirement already satisfied: shapely>=2 in /opt/python/lib/python3.13/site-packages (from pynsee) (2.1.2)
# Requirement already satisfied: requests>=2.32 in /opt/python/lib/python3.13/site-packages (from pynsee) (2.32.5)
# Collecting requests-ratelimiter>=0.7 (from pynsee)
#   Downloading requests_ratelimiter-0.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting openpyxl (from pynsee)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/python/lib/python3.13/site-packages (from geopandas<2.0,>=1.0->pynsee) (2.3.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/python/lib/python3.13/site-packages (from geopandas<2.0,>=1.0->pynsee) (0.12.1)
# Requirement already satisfied: packaging in /opt/python/lib/python3.13/site-packages (from geopandas<2.0,>=1.0->pynsee) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/python/lib/python3.13/site-packages (from geopandas<2.0,>=1.0->pynsee) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas<3.0,>=2.2.0->pynsee) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas<3.0,>=2.2.0->pynsee) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas<3.0,>=2.2.0->pynsee) (2025.3)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas<2.0,>=1.0->pynsee) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=2.2.0->pynsee) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.32->pynsee) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests>=2.32->pynsee) (3.11)
# Collecting pyrate-limiter<3.0 (from requests-ratelimiter>=0.7->pynsee)
#   Downloading pyrate_limiter-2.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting et-xmlfile (from openpyxl->pynsee)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading pynsee-0.2.4-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 99.0 MB/s  0:00:00
# Downloading requests_ratelimiter-0.7.0-py3-none-any.whl (9.3 kB)
# Downloading pyrate_limiter-2.10.0-py3-none-any.whl (16 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: unidecode, pyrate-limiter, et-xmlfile, requests-ratelimiter, openpyxl, pynsee
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pynsee]2m5/6 [pynsee]l]miter]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 pynsee-0.2.4 pyrate-limiter-2.10.0 requests-ratelimiter-0.7.0 unidecode-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Créons un data frame à partir du CSV

chemin_fichier = '../data/country_risk_premiums.csv'
df_crp = pd.read_csv(chemin_fichier)
df_crp.head(20)
# Out:
#                                     Country  Adj. Default Spread  \
# 0                                 Abu Dhabi                 0.49
# 1                                   Albania                 3.56
# 2                                   Algeria                 2.98
# 3   Andorra               (Principality of)                 1.58
# 4                                    Angola                 6.44
# 5                                  Anguilla                 6.01
# 6           Antigua &               Barbuda                 6.01
# 7                                 Argentina                11.88
# 8                                   Armenia                 3.56
# 9                                     Aruba                 2.18
# 10                                Australia                 0.00
# 11                                  Austria                 0.40
# 12                               Azerbaijan                 2.48
# 13                                  Bahamas                 4.46
# 14                                  Bahrain                 5.45
# 15                               Bangladesh                 5.45
# 16                                 Barbados                 6.44
# 17                                  Belarus                17.50
# 18                                  Belgium                 0.59
# 19                                   Belize                 7.43
#
#     Equity Risk Premium  Country Risk Premium  Corporate Tax Rate  \
# 0                  4.99                  0.66               15.00
# 1                  9.13                  4.80               15.00
# 2                  8.35                  4.02               15.00
# 3                  6.46                  2.13               18.98
# 4                 13.01                  8.68               25.00
# 5                 12.44                  8.11               25.23
# 6                 12.43                  8.10               25.23
# 7                 20.35                 16.02               35.00
# 8                  9.13                  4.80               18.00
# 9                  7.26                  2.93               25.00
# 10                 4.33                  0.00               30.00
# 11                 4.86                  0.53               24.00
# 12                 7.67                  3.34               20.00
# 13                10.34                  6.01                0.00
# 14                11.67                  7.34                0.00
# 15                11.67                  7.34               30.00
# 16                13.01                  8.68                5.50
# 17                27.92                 23.59               18.00
# 18                 5.13                  0.80               25.00
# 19                14.34                 10.01               28.53
#
#    Moody's rating
# 0             Aa2
# 1             Ba3
# 2              NR
# 3            Baa1
# 4              B3
# 5              NR
# 6              NR
# 7              Ca
# 8             Ba3
# 9            Baa3
# 10            Aaa
# 11            Aa1
# 12            Ba1
# 13             B1
# 14             B2
# 15             B2
# 16             B3
# 17              C
# 18            Aa3
# 19           Caa1
